# %% [markdown]
# # Thực hành: Cấu trúc điều kiện

# %% [markdown]
# ### Bài 1: Viết chương trình nhập vào chiều dài và chiều rộng của hình chữ nhật và cho biết đó có phải là hình vuông hay không.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
length = float(input("Input the length of the rectangle: "))
width = float(input("Input the width of the rectangle: "))
if length==0 and width==0:
    print ("THIS IS WRONG!!!")
else:
    if length == width:
        print ("The rectangle is a square.")
    else:
        print ("The rectangle is not a square.")
# Out:
# Input the length of the rectangle: 10
# Input the width of the rectangle: 2
# The rectangle is not a square.

# %% [markdown]
# ### Bài 2: Viết chương trình nhập vào 2 số a, b và in ra số lớn nhất

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = float(input("a = "))
b = float(input("b = "))
if  a > b:
    print(a)
else: 
    print(b)
# Out:
# a = 12
# b = 4
# 12.0

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào 3 số a, b, c và in ra số lớn nhất

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = float(input("a = "))
b = float(input("b = "))
c = float(input("c = "))
largest_num = a
if b > largest_num:
  largest_num = b
if c > largest_num:
  largest_num = c

print("The largest number is:", largest_num)
# Out:
# a = 12
# b = 11
# c = 10
# The largest number is: 12.0

# %% [markdown]
# ### Bài 4: Viết chương trình nhập vào số tuổi của 3 người và cho biết ai là người trẻ nhất và ai là người lớn tuổi nhất

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
first_person_age = int(input("Please input the age of the first person: "))
second_person_age = int(input("Please input the age of the second person: "))
third_person_age = int(input("Please input the age of the third person: "))

oldest = first_person_age
youngest = first_person_age

oldest_person = 'first person'
youngest_person = 'first person'

if second_person_age < youngest:
  youngest = second_person_age
  youngest_person = 'second person'

if third_person_age < youngest:
  youngest = third_person_age
  youngest_person = 'third person'

if second_person_age > oldest:
  oldest = second_person_age
  oldest_person = 'second person'

if third_person_age > oldest:
  oldest = third_person_age
  oldest_person = 'third person'

print("The youngest person is", youngest, "years old, which is the", youngest_person)
print("The oldest person is", oldest, "years old, which is the", oldest_person)
# Out:
# Please input the age of the first person: 10
# Please input the age of the second person: 20
# Please input the age of the third person: 30
# The youngest person is 10 years old, which is the first person
# The oldest person is 30 years old, which is the third person

# %%
first_person = int(input("Please input the age of the first person: "))
second_person = int(input("Please input the age of the second person: "))
third_person = int(input("Please input the age of the third person: "))
oldest = first_person
youngest = first_person
if second_person < youngest:
  youngest = second_person
if third_person < youngest:
  youngest = third_person
if second_person > oldest:
  oldest = second_person
if third_person > oldest:
  oldest = third_person

if first_person == oldest:
  print("The first person is the oldest.")
elif second_person == oldest:
    print("The second person is the oldest.")
else: print("The third person is the oldest.")


if first_person == youngest:
  print("The first person is the youngest.")
elif second_person == youngest:
    print("The second person is the youngest.")
else: print("The third person is the youngest.")
# Out:
# Please input the age of the first person: 10
# Please input the age of the second person: 20
# Please input the age of the third person: 30
# The third person is the oldest.
# The first person is the youngest.

# %% [markdown]
# ### Bài 5: Viết chương trình nhập vào một số bất kỳ và in ra giá trị tuyệt đối của số đó

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
number = float(input("Input a number: "))

absolute_number = abs(number)

print("The absolute value of", number, "is", absolute_number)
# Out:
# Input a number: -12
# The absolute value of -12.0 is 12.0

# %% [markdown]
# ### Bài 6: Học viên sẽ không đủ điều kiện thi nếu tỉ lệ có mặt nhỏ hơn 75%. Viết chương trình nhập vào tổng số buổi học của một khóa học và tổng số buổi học mà học viên tham gia. Sau đó cho biết học viên đó có đủ điều kiện thi hay không.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
total_sessions = int(input("Input the total number of sessions in the course: "))
attendance = int(input("Input the number of sessions that the student attended: "))

attendance_rate = attendance / total_sessions * 100

if attendance_rate >= 75:
  print("The student is eligible for the exam.")
else:
  print("The student is not eligible for the exam.")
# Out:
# Input the total number of sessions in the course: 60
# Input the number of sessions that the student attended: 50
# The student is eligible for the exam.

# %% [markdown]
# ### Bài 7: Một công ty vận tải có cách tính chi phí giao hàng như sau:
# 1. 10kilogram đầu tiên: \$5/kg
# 2. Từ kilogram thứ 11 đến 20: \$7/kg
# 3. Từ kilogram thứ 20 trở lên: \$10/kg
#
# Viết chương trình nhập vào số kg cần giao(số nguyên) và in ra chi phí giao hàng tương ứng

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kilograms = int(input("Input the number of kilograms need to be delivered: "))

if kilograms <= 10:
  delivery_cost = kilograms * 5
elif kilograms > 10 and kilograms <= 20:
  delivery_cost = 10 * 5 + (kilograms - 10) * 7
else:
  delivery_cost = 10 * 12 + (kilograms - 20) * 10

print("The delivery cost is $", delivery_cost)
# Out:
# Input the number of kilograms need to be delivered: 12
# The delivery cost is $ 64

# %% [markdown]
# ### Bài 8: Viết chương trình nhập vào số năm và cho biết năm đó là năm nhuận hay năm không nhuận.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
year = int(input("Input the year: "))

if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("The year is a leap year.")
    else:
      print("The year is not a leap year.")
  else:
    print("The year is a leap year.")
else:
  print("The year is not a leap year.")
# Out:
# Input the year: 2024
# The year is a leap year.

# %% [markdown]
# ### Bài 9: Viết chương trình nhập vào 1 số từ 1 đến 7 và in ra số ngày trong tuần tương ứng như sau:
# - 1: Sunday
# - 2: Monday
# - 3: Tuesday
# - 4: Wednesday
# - 5: Thursday
# - 6: Friday
# - 7: Saturday

# %%
day_number = int(input("Please input a number from 1 to 7 prepresent for a day in week: "))

if day_number == 1:
  print("Sunday")
elif day_number == 2:
  print("Monday")
elif day_number == 3:
  print("Tuesday")
elif day_number == 4:
  print("Wednesday")
elif day_number == 5:
  print("Thursday")
elif day_number == 6:
  print("Friday")
elif day_number == 7:
  print("Saturday")
else:
  print("Your input number is not correct")
# Out:
# Please input a number from 1 to 7: 1
# Sunday

# %% [markdown]
# ### Bài 10:
# Tại một cửa hàng nọ có menu như sau:
#
# 1. Gà rán giá 35000
# 2. Hamburger giá 50000
# 3. Pesi giá 10000
#
# Nhập số lượng món hàng cần mua
#
# Tính và in ra tổng giá tiền
#
# Nếu giá trị đơn hàng trên 2 triệu, giảm 10% cho khách, trên 4 triệu, giảm 15%
#
# Tính và in ra tổng giá tiền được giảm
#
# Tính và in ra tổng giá tiền khách cần trả
#
# In ra dòng chữ "Cảm ơn quý khách đã mua hàng"

# %%
"""Ví dụ:
Nhập số lượng gà rán khách mua:100
Nhập số lượng hamburger khách mua:100
Nhập số lượng pesi khách mua:15
Tổng giá tiền đơn hàng là: 8.650.000
Tổng tiền được giảm là: 1.297.500
Tổng tiền phải thanh toán: 7.352.500
Cảm ơn quý khách đã mua
"""

# %%
quantity_1 = int(input("Input the quantity of fried chicken: "))
quantity_2 = int(input("Input the quantity of hamburger: "))
quantity_3 = int(input("Input the quantity of pepsi: "))

total_price = quantity_1*35000 + quantity_2*50000 + quantity_1*10000
print(f"Your order is {quantity_1} chicken, {quantity_2} hamburger, {quantity_3} pepsi. Total {total_price} vnd")

if total_price > 2000000:
  discount = 0.1
elif total_price > 4000000:
  discount = 0.15
else:
  discount = 0

total_discount = int(total_price * discount)
final_price = total_price - total_discount

print(f'''Total price: {total_price} vnd
Discount: {total_discount} vnd''')

print("Final price:", final_price, "vnd")

print("Thank you for your purchase")
# Out:
# Input the quantity of fried chicken: 30
# Input the quantity of hamburger: 30
# Input the quantity of pepsi: 40
# Your order is 30 chicken, 30 hamburger, 40 pepsi. Total 2850000 vnd
# Total price: 2850000 vnd
# Discount: 285000 vnd
# Final price: 2565000 vnd
# Thank you for your purchase

# %% [markdown]
# ### Bài 11:
#
# Nhập vào chiều cao (cm) và cân nặng (kg), tính số BMI và xét rồi xin kết quả theo dữ liệu sau:
#
# - BMI < 16: Gầy cấp độ III
# - 16 <= BMI < 17:  Gầy cấp độ II
# - 17<= BMI < 18.5: Gầy cấp độ I
# - 18.5 <= BMI < 25: Bình thường
# - 25 <= BMI < 30: Thừa cân
# - 30 <= BMI < 35 : Béo phì cấp độ I
# - 35 <= BMI < 40: Béo phì cấp độ II
# - BMI > 40: Béo phì cấp độ III

# %%
height = float(input("Enter your height in centimeters: "))
weight = float(input("Enter your weight in kilograms: "))

bmi = round(weight / (height / 100) ** 2,2)

if bmi < 16:
  classification = "Extremely thin (Level III)"
elif bmi < 17:
  classification = "Very thin (Level II)"
elif bmi < 18.5:
  classification = "Underweight (Level I)"
elif bmi < 25:
  classification = "Normal"
elif bmi < 30:
  classification = "Overweight"
elif bmi < 35:
  classification = "Obese Level I"
elif bmi < 40:
  classification = "Obese Level II"
else:
  classification = "Obese Level III"

print("Your BMI is:", bmi)
print("Your classification is:", classification)
# Out:
# Enter your height in centimeters: 168
# Enter your weight in kilograms: 58
# Your BMI is: 20.55
# Your classification is: Normal

# %% [markdown]
# ### Bài 12: Tìm ra người lớn tuổi nhất trong 4 người thông qua số tuổi nhập vào từ người dùng.

# %%
age_1 = int(input("Input the age of 1st person: "))
age_2 = int(input("Input the age of 2nd person: "))
age_3 = int(input("Input the age of 3rd person: "))
age_4 = int(input("Input the age of 4th person: "))


oldest_person_age = age_1
oldest_person = "the first person"

if age_2 > oldest_person_age:
    oldest_person_age = age_2
    oldest_person = "the second person"

if age_3 > oldest_person_age:
    oldest_person_age = age_3
    oldest_person = "the third person"
    
if age_4 > oldest_person_age:
    oldest_person_age = age_4
    oldest_person = "the forth person"

print("The oldest person is", oldest_person_age, "years old, which is the", oldest_person)
# Out:
# Input the age of 1st person: 10
# Input the age of 2nd person: 20
# Input the age of 3rd person: 30
# Input the age of 4th person: 40
# The oldest person is 40 years old, which is the the forth person

# %% [markdown]
# ## BONUS

# %% [markdown]
# ### Bài 13: Viết chương trình nhập vào số đo 3 cạnh của tam giác và cho biết đó là tam giác cân, tam giác đều hay tam giác vô hướng
# Ghi chú:
#  - Tam giác cân là tam giác có 2 cạnh bằng nhau
#  - Tam giác đều là tam giác có 3 cạnh bằng nhau
#  - Tam giác vô hướng là tam giác không có cạnh nào bằng nhau

# %%
a = float(input("Input the measure of side a of the triangle: "))
b = float(input("Input the measure of side b of the triangle: " ))
c = float(input("Input the measure of side c of the triangle: "))

if a + b > c and b + c > a and a + c > b:

  if a == b == c:
    print("The triangle is equilateral")

  elif a == b or b == c or c == a:
    print("The triangle is isosceles")

  else:
    print("The triangle is scalene")

else:
  print("The three sides cannot form a triangle")
# Out:
# Input the measure of side a of the triangle: 2
# Input the measure of side b of the triangle: 3
# Input the measure of side c of the triangle: 4
# The triangle is scalene

# %% [markdown]
# ### Bài 14: Viết chương trình nhập vào 3 số nguyên khác nhau và in ra số lớn thứ hai

# %%
int1 = int(input("Input the first integer number: "))
int2 = int(input("Input the second integer number: "))
int3 = int(input("Input the third integer number: "))

second_largest = 0

if (int1 > int2 and int1 < int3) or (int1 > int3 and int1 < int2):
  second_largest = int1

if (int2 > int1 and int2 < int3) or (int2 > int3 and int2 < int1):
  second_largest = int2

if (int3 > int2 and int3< int1) or (int3 > int1 and int3 < int2):
  second_largest = int3

print(f"The second largest number is {second_largest}")
# Out:
# Input the first integer number: 2
# Input the second integer number: 10
# Input the third integer number: 5
# The second largest number is 5

# %% [markdown]
# ### Bài 15: Xem đoạn code sau:
# ![image.png](attachment:image.png)
# Nếu i, j, k có các giá trị ban đầu là:
#
# a. i = 3, j = 5, k = 7
#
# b. i = 13, j = 15, k = 13
#
# Thì giá trị của i, j, k sau khi thực hiện đoạn code trên là bao nhiêu?(kiểm tra bằng cách tính nhẩm, không code lại)

# %%
a. i = 7, j = 5, k = 7
b. i=j=k=13

# %% [markdown]
# ### Bài 16: Viết một chương trình thực hiện phép tính đơn giản như sau:
# ```
#     Nhập số thứ nhất: 16
#     Nhập số thứ hai: 9
#     Nhập toán tử (+, -, *, /): +
#     Kết quả: 16 + 9 = 25
# ```

# %%
num1 = int(input("Input the first number: "))
num2 = int(input("Input the second number: "))
operator = input("Enter operators (+, -, *, /): ")

if operator == "+":
  result = num1 + num2
elif operator == "-":
  result = num1 - num2
elif operator == "*":
  result = num1 * num2
elif operator == "/":
  result = num1 / num2

print(f"Result: {num1} {operator} {num2} = {result}")
# Out:
# Input the first number: 2
# Input the second number: 4
# Enter operators (+, -, *, /): /
# Result: 2 / 4 = 0.5

# %% [markdown]
# ### Bài 17: Viết chương trình nhập vào 3 số nguyên và in ra màn hình theo thứ tự từ lớn đến bé.

# %%
num1 = int(input("Input the first integer number: "))
num2 = int(input("Input the second integer number: "))
num3 = int(input("Input the third integer number: "))

largest = 0 
second_largest = 0
smallest = 0

if (num1 > num2 and num1 > num3):
  largest = num1
  if (num2 > num3):
    second_largest = num2
    smallest = num3
  else:
    second_largest = num3
    smallest = num2

if (num2 > num1 and num2 > num3):
  largest = num2
  if (num1 > num3):
    second_largest = num1
    smallest = num3
  else:
    second_largest = num3
    smallest = num1  

if (num3 > num1 and num3 > num2):
  largest = num3
  if (num1 > num2):
    second_largest = num1
    smallest = num2
  else:
    second_largest = num2
    smallest = num1 

print(f"The numbers in order from largest to smallest are: {largest}, {second_largest}, {smallest}")
# Out:
# Input the first integer number: 12
# Input the second integer number: 14
# Input the third integer number: 55
# The numbers in order from largest to smallest are: 55, 14, 12
